# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %% [markdown]
# ## Question 1
# #### Consider only the below columns and prepare a prediction model for predicting Price.
# #### Corolla<-Corolla[c("Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight")]

# %%
corolla = pd.read_csv('/Users/apple/Downloads/ToyotaCorolla.csv')

# %%
corolla
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3     �TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  ...  \
# ...

# %%
Corolla=corolla[["Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight"]]

# %%
Corolla
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
Corolla.columns
# Out:
# Index(['Price', 'Age_08_04', 'KM', 'HP', 'cc', 'Doors', 'Gears',
#        'Quarterly_Tax', 'Weight'],
#       dtype='object')

# %%
Corolla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
Corolla.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
Corolla.isna().sum()
# Out:
# Price            0
# Age_08_04        0
# KM               0
# HP               0
# cc               0
# Doors            0
# Gears            0
# Quarterly_Tax    0
# Weight           0
# dtype: int64

# %%
Corolla.corr()
# Out:
#                   Price  Age_08_04        KM        HP        cc     Doors  \
# Price          1.000000  -0.876590 -0.569960  0.314990  0.126389  0.185326
# Age_08_04     -0.876590   1.000000  0.505672 -0.156622 -0.098084 -0.148359
# KM            -0.569960   0.505672  1.000000 -0.333538  0.102683 -0.036197
# HP             0.314990  -0.156622 -0.333538  1.000000  0.035856  0.092424
# cc             0.126389  -0.098084  0.102683  0.035856  1.000000  0.079903
# Doors          0.185326  -0.148359 -0.036197  0.092424  0.079903  1.000000
# Gears          0.063104  -0.005364  0.015023  0.209477  0.014629 -0.160141
# Quarterly_Tax  0.219197  -0.198431  0.278165 -0.298432  0.306996  0.109363
# Weight         0.581198  -0.470253 -0.028598  0.089614  0.335637  0.302618
#
#                   Gears  Quarterly_Tax    Weight
# Price          0.063104       0.219197  0.581198
# Age_08_04     -0.005364      -0.198431 -0.470253
# KM             0.015023       0.278165 -0.028598
# ...

# %%
sns.set_style(style='darkgrid')
sns.pairplot(Corolla)

# %%
import statsmodels.formula.api as smf 
model = smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=Corolla).fit()

# %%
model.params
# Out:
# Intercept       -5573.106358
# Age_08_04        -121.658402
# KM                 -0.020817
# HP                 31.680906
# cc                 -0.121100
# Doors              -1.616641
# Gears             594.319936
# Quarterly_Tax       3.949081
# Weight             16.958632
# dtype: float64

# %%
(model.rsquared,model.rsquared_adj)
# Out:
# (0.8637627463428191, 0.8629989775766962)

# %%
print(model.tvalues, '\n', model.pvalues)
# Out:
# Intercept        -3.948666
# Age_08_04       -46.511852
# KM              -16.621622
# HP               11.241018
# cc               -1.344222
# Doors            -0.040410
# Gears             3.016007
# Quarterly_Tax     3.014535
# Weight           15.879803
# dtype: float64
#  Intercept         8.241949e-05
# Age_08_04        3.354724e-288
# KM                7.538439e-57
# HP                3.757218e-28
# cc                1.790902e-01
# Doors             9.677716e-01
# Gears             2.606549e-03
# Quarterly_Tax     2.619148e-03
# Weight            2.048576e-52
# dtype: float64

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
list(np.where(model.resid>6000))
# Out:
# [array([147, 523])]

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(Corolla)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c),np.max(c))
# Out:
# (80, 79.52010624138178)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(model)
plt.show()

# %%
k = Corolla.shape[1]
n = Corolla.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.020891364902506964

# %%
Corolla[Corolla.index.isin([80])]
# Out:
#     Price  Age_08_04     KM   HP     cc  Doors  Gears  Quarterly_Tax  Weight
# 80  18950         25  20019  110  16000      5      5            100    1180

# %%
Corolla1=Corolla

# %%
Corolla2=Corolla1.drop(Corolla1.index[[80]],axis=0).reset_index()

# %%
Final_model=smf.ols('Price~Age_08_04+KM+HP+cc+Doors+Gears+Quarterly_Tax+Weight',data=Corolla2).fit()

# %%
Final_model.params
# Out:
# Intercept       -6284.740060
# Age_08_04        -120.455049
# KM                 -0.017849
# HP                 39.346295
# cc                 -2.524177
# Doors             -27.228488
# Gears             523.941556
# Quarterly_Tax       9.043968
# Weight             20.165459
# dtype: float64

# %%
(Final_model.rsquared,Final_model.rsquared_adj)
# Out:
# (0.8693790488655818, 0.8686462525057814)

# %%
new_data=pd.DataFrame({'Age_08_04':2.5,"KM":30560,"HP":73,"cc":1500,"Doors":4,"Gears":5,"Quarterly_Tax":189,"Weight":1100},index=[1])

# %%
Final_model.predict(new_data)
# Out:
# 1    18356.793776
# dtype: float64

# %% [markdown]
# ## Question 2

# %% [markdown]
# #### Consider only the below columns and prepare a prediction model for predicting Price.
#
# #### Corolla<-Corolla[c("Price","Age_08_04","KM","HP","cc","Doors","Gears","Quarterly_Tax","Weight")]

# %%
startup=pd.read_csv('/Users/apple/Downloads/50_Startups.csv')

# %%
startup
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
startup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
startup.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
startup.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
startup.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
sns.set_style(style='darkgrid')
sns.pairplot(startup)

# %%
startup.rename(columns={"R&D Spend":"RandD_Spend","Marketing Spend":"Marketing_Spend"}, inplace= True)

# %%
startup.head()
# Out:
#    RandD_Spend  Administration  Marketing_Spend       State     Profit
# 0    165349.20       136897.80        471784.10    New York  192261.83
# 1    162597.70       151377.59        443898.53  California  191792.06
# 2    153441.51       101145.55        407934.54     Florida  191050.39
# 3    144372.41       118671.85        383199.62    New York  182901.99
# 4    142107.34        91391.77        366168.42     Florida  166187.94

# %%
import statsmodels.formula.api as smf 
startup_model = smf.ols('Profit~RandD_Spend+Administration+Marketing_Spend+State',data=startup).fit()

# %%
startup_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     169.9
# Date:                Tue, 24 Aug 2021   Prob (F-statistic):           1.34e-27
# Time:                        18:01:03   Log-Likelihood:                -525.38
# No. Observations:                  50   AIC:                             1063.
# Df Residuals:                      44   BIC:                             1074.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(startup_model.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
model_influence = startup_model.get_influence()
(c1, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(startup)), np.round(c1, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c1),np.max(c1))
# Out:
# (49, 0.2639594358692202)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(startup_model)
plt.show()

# %%
k = startup.shape[1]
n = startup.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.36

# %%
startup[startup.index.isin([49])]
# Out:
#     RandD_Spend  Administration  Marketing_Spend       State   Profit
# 49          0.0        116983.8         45173.06  California  14681.4

# %%
startup1=startup

# %%
startup2=startup1.drop(startup1.index[[49]],axis=0).reset_index()

# %%
startup2.head()
# Out:
#    index  RandD_Spend  Administration  Marketing_Spend       State     Profit
# 0      0    165349.20       136897.80        471784.10    New York  192261.83
# 1      1    162597.70       151377.59        443898.53  California  191792.06
# 2      2    153441.51       101145.55        407934.54     Florida  191050.39
# 3      3    144372.41       118671.85        383199.62    New York  182901.99
# 4      4    142107.34        91391.77        366168.42     Florida  166187.94

# %%
import statsmodels.formula.api as smf 
startup_model2 = smf.ols('Profit~RandD_Spend+Administration+Marketing_Spend+State',data=startup2).fit()

# %%
startup_model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.957
# Method:                 Least Squares   F-statistic:                     216.6
# Date:                Tue, 24 Aug 2021   Prob (F-statistic):           2.51e-29
# Time:                        18:01:03   Log-Likelihood:                -505.97
# No. Observations:                  49   AIC:                             1024.
# Df Residuals:                      43   BIC:                             1035.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(startup_model2.resid,line='q') # line = 45 to draw the diagnoal line
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
model_influence = startup_model2.get_influence()
(c2, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(startup2)), np.round(c2, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
(np.argmax(c2),np.max(c2))
# Out:
# (48, 0.2841162050065694)

# %%
from statsmodels.graphics.regressionplots import influence_plot
influence_plot(startup_model2)
plt.show()

# %%
k = startup2.shape[1]
n = startup2.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.42857142857142855

# %%
startup2[startup2.index.isin([48])]
# Out:
#     index  RandD_Spend  Administration  Marketing_Spend     State    Profit
# 48     48       542.05        51743.15              0.0  New York  35673.41

# %%
startup3=startup2

# %%
startup_final=startup3.drop(startup3.index[[48]],axis=0).reset_index()

# %%
startup_final.head()
# Out:
#    level_0  index  RandD_Spend  Administration  Marketing_Spend       State  \
# 0        0      0    165349.20       136897.80        471784.10    New York
# 1        1      1    162597.70       151377.59        443898.53  California
# 2        2      2    153441.51       101145.55        407934.54     Florida
# 3        3      3    144372.41       118671.85        383199.62    New York
# 4        4      4    142107.34        91391.77        366168.42     Florida
#
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
startup_final.drop(['index'],axis=1, inplace= True)

# %%
startup_final.head()
# Out:
#    level_0  RandD_Spend  Administration  Marketing_Spend       State  \
# 0        0    165349.20       136897.80        471784.10    New York
# 1        1    162597.70       151377.59        443898.53  California
# 2        2    153441.51       101145.55        407934.54     Florida
# 3        3    144372.41       118671.85        383199.62    New York
# 4        4    142107.34        91391.77        366168.42     Florida
#
#       Profit
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
startup_final.drop(['level_0'],axis=1, inplace= True)

# %%
startup_final.head()
# Out:
#    RandD_Spend  Administration  Marketing_Spend       State     Profit
# 0    165349.20       136897.80        471784.10    New York  192261.83
# 1    162597.70       151377.59        443898.53  California  191792.06
# 2    153441.51       101145.55        407934.54     Florida  191050.39
# 3    144372.41       118671.85        383199.62    New York  182901.99
# 4    142107.34        91391.77        366168.42     Florida  166187.94

# %%
import statsmodels.formula.api as smf 
startup_model3 = smf.ols('Profit~RandD_Spend+Administration+Marketing_Spend+State',data=startup_final).fit()

# %%
startup_model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.958
# Method:                 Least Squares   F-statistic:                     217.6
# Date:                Tue, 24 Aug 2021   Prob (F-statistic):           7.02e-29
# Time:                        18:01:04   Log-Likelihood:                -493.23
# No. Observations:                  48   AIC:                             998.5
# Df Residuals:                      42   BIC:                             1010.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(startup_model3.fittedvalues),
            get_standardized_values(startup_model3.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
new_startup=pd.DataFrame({"RandD_Spend":20,"Administration":30,"Marketing_Spend":17,"State":'New York'},index=[1])

# %%
startup_model3.predict(new_startup)
# Out:
# 1    58738.425523
# dtype: float64
